# %% [markdown]
# # Input and output parameters
#
# Input paremters list
#
# IN_R - Index position row (Specify the dot/fuidical based on row and colomn based name)
# IN_C - Index positon column
# CP_X - Calcualted X axis encoder value of the dot.
