# %% [markdown]
# Connecting to python jupter kernel
#
# ```markdown
# cd ..
# .\py313\Scripts\activate
# cd .\pba_vision_mapping\
# jupyter notebook
# ```

# %%
import pandas as pd
import numpy as np
